# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import random
import warnings

warnings.filterwarnings('ignore')

x = pd.read_csv(r"C:\Users\Ayan\Desktop\Untitled Folder\x2022.csv")
y = pd.read_csv(r"C:\Users\Ayan\Desktop\Untitled Folder\y2022.csv")
x.head()
# Out:
#    Unnamed: 0  Temperatura_Media_C  Temperatura_Maxima_C  Final_de_Semana
# 0           0                27.30                  32.5              0.0
# 1           1                27.02                  33.5              0.0
# 2           2                24.82                  29.9              1.0
# 3           3                23.98                  28.6              1.0
# 4           4                23.82                  28.3              0.0

# %%
x = x.drop(['Unnamed: 0',], axis=1).values
#x = df['Temperatura_Maxima_C'].values
y = y['Consumo_de_cerveja_litros'].values

# %%
print(x)
# Out:
# [[27.3  32.5   0.  ]
#  [27.02 33.5   0.  ]
#  [24.82 29.9   1.  ]
#  [23.98 28.6   1.  ]
#  [23.82 28.3   0.  ]
#  [24.   33.7   0.  ]
#  [28.2  34.    0.  ]
#  [26.76 34.2   1.  ]
#  [27.62 34.8   1.  ]
#  [25.96 35.4   0.  ]
#  [25.52 34.8   0.  ]
#  [25.96 34.    0.  ]
#  [25.86 32.8   0.  ]
#  [26.5  32.7   0.  ]
#  [28.86 35.8   1.  ]
#  [28.26 35.6   1.  ]
#  [28.22 36.5   0.  ]
#  [27.68 35.6   0.  ]
#  [25.32 30.9   0.  ]
#  [21.04 26.1   0.  ]
#  [24.4  30.    1.  ]
#  [23.6  28.7   0.  ]
#  [25.68 29.9   0.  ]
#  [25.   29.2   0.  ]
#  [22.8  26.9   0.  ]
#  [21.64 24.3   1.  ]
#  [24.16 28.    1.  ]
#  [22.48 26.5   0.  ]
#  [23.16 31.1   0.  ]
#  [22.12 23.7   0.  ]
#  [20.28 22.9   0.  ]
#  [24.   30.7   0.  ]
#  [25.38 30.4   0.  ]
#  [27.66 32.7   0.  ]
#  [25.54 32.1   0.  ]
#  [24.32 31.6   1.  ]
#  [23.92 28.5   0.  ]
#  [24.72 28.2   0.  ]
#  [25.2  31.1   1.  ]
#  [24.44 30.8   1.  ]
#  [25.4  31.4   0.  ]
#  [24.3  31.9   0.  ]
#  [22.24 29.3   0.  ]
# ...

# %%
print(y)
# Out:
# [25.461 28.972 30.814 29.799 28.9   29.732 24.886 37.937 36.254 25.743
#  26.99  31.825 25.724 29.938 37.69  30.524 29.265 35.127 29.13  21.784
#  31.088 29.972 22.603 22.696 26.845 27.03  32.057 24.097 31.655 24.738
#  19.95  24.062 26.805 26.389 24.219 30.231 22.922 24.567 30.943 30.825
#  25.692 26.959 25.366 26.241 26.467 27.475 28.749 24.146 22.988 30.3
#  22.654 22.409 21.281 32.872 20.167 23.628 24.213 25.855 21.617 22.401
#  27.989 24.974 29.76  26.116 24.925 21.979 22.116 24.867 33.45  32.713
#  22.356 21.004 23.362 20.298 24.862 30.505 25.07  22.62  22.001 23.469
#  33.822 28.028 31.108 19.113 24.388 27.42  30.479 21.838 20.812 19.761
#  20.452 17.939 25.272 28.049 25.317 20.68  19.143 18.146 25.489 23.537
#  19.052 17.287 20.3   20.538 23.702 28.411 21.073 24.215 19.525 20.786
#  20.429 27.25  31.387 26.075 22.162 24.258 24.683 21.245 25.937 26.081
#  16.228 20.106 21.055 22.772 25.142 31.129 30.498 26.15  21.327 22.008
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x,y,test_size = 0.2,random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
mod = LinearRegression()
#mod.fit(X_train.reshape(-1, 1),Y_train)
mod.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
#y_pred = mod.predict(X_test.reshape(-1, 1))
y_pred = mod.predict(X_test)

print(y_pred)
# Out:
# [23.0309485  25.15500632 28.73079719 34.01982609 31.76559605 23.86707582
#  24.09983686 26.94413462 24.3610948  21.87129043 28.71179926 35.9594584
#  29.02065347 30.39974538 26.82620187 23.46656705 24.71072952 18.63795545
#  24.93406438 28.85959142 30.2349124  20.51926011 23.13311697 23.92976899
#  28.62250899 21.78910618 25.31557522 25.23472483 22.73690093 28.6224362
#  29.11662942 23.96586506 35.37797614 20.75392095 30.0462383  19.51207863
#  29.16602404 25.83337802 26.1530364  29.13989143 29.0410294  21.47317459
#  29.94508477 28.24479773 24.63333115 27.76079951 29.57832327 25.99915316
#  34.90576838 29.24152261 23.43096412 23.38536909 21.95544726 20.55626968
#  25.1331223  22.4213897  19.95058326 30.62345647 25.21150696 18.71394717]

# %%
from sklearn.metrics import r2_score
x = r2_score(Y_test,y_pred) *100
print(x)
# Out:
# 71.58069888056428

# %%
plt.figure(figsize=(15,10))
plt.scatter(Y_test,y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted')
# Out:
# Text(0.5, 1.0, 'Actual vs Predicted')
